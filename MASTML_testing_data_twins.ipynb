# %%
# Import needed MASTML modules

from mastml.mastml import Mastml
from mastml.datasets import LocalDatasets, SklearnDatasets, FoundryDatasets, FigshareDatasets, DataUtilities, DataCleaning
from mastml.preprocessing import SklearnPreprocessor, MeanStdevScaler
from mastml.models import SklearnModel
from mastml.data_splitters import SklearnDataSplitter, NoSplit, LeaveOutTwinCV
from mastml.plots import Histogram, Scatter
from mastml.feature_selectors import EnsembleModelFeatureSelector, NoSelect
from mastml.feature_generators import ElementalFeatureGenerator
# Out:
# To import data from figshare, manually install figshare via git clone of git clone https://github.com/cognoma/figshare.git
# If you want to use XGBoost models, please manually install xgboost package

# %%
# Initialize the MASTML run, write savepath and metadata file

mastml = Mastml(savepath='results/test_output')
savepath = mastml.get_savepath
mastml_metadata = mastml.get_mastml_metadata
# Out:
# results/test_output not empty. Renaming...

# %%
# Download diffusion data from Figshare (done previously)

#article_id = 7418492
#FigshareDatasets().download_data(article_id=article_id)

# %%
# Load in diffusion data downloaded from Figshare 

target = 'E_regression.1'
extra_columns = ['E_regression', 'Material compositions 1', 'Material compositions 2', 'Hop activation barrier']
d = LocalDatasets(file_path='figshare_7418492/All_Model_Data_missing.xlsx', 
                  target=target, 
                  extra_columns=extra_columns, 
                  as_frame=True)

X, y = d.load_data()
# Out:
# WARNING: feature_names not specified but target was specified. Assuming all columns except target and extra columns are features

# %%
X
# Out:
#      valence_composition_average  phi_composition_average  \
# 0                            NaN                    4.350
# 1                            NaN                    4.725
# 2                            NaN                    4.500
# 3                            NaN                    4.400
# 4                            NaN                    4.640
# ..                           ...                      ...
# 403                          4.5                    3.750
# 404                          4.5                    3.750
# 405                          4.0                    3.625
# 406                          4.0                    3.525
# 407                          4.0                    3.800
#
#      NdValence_composition_average  MiracleRadius_composition_average  \
# 0                             10.0                              144.0
# 1                              8.5                              134.5
# 2                              7.5                              137.0
# 3                             10.0                              135.0
# 4                              8.0                              134.5
# ..                             ...                                ...
# 403                            3.0                              150.5
# 404                            2.5                              151.5
# 405                            2.0                              150.0
# 406                            2.0                              158.0
# 407                            6.0                              156.5
#
#      GSestFCClatcnt_composition_average  \
# 0                              4.027313
# 1                              3.737485
# 2                              3.788936
# 3                              3.782567
# 4                              3.764269
# ..                                  ...
# 403                            4.350534
# 404                            4.348236
# 405                            4.291886
# 406                            4.494239
# 407                            4.816669
#
#      SecondIonizationEnergy_composition_average  \
# 0                                       21.4900
# 1                                       19.2750
# 2                                       18.9950
# 3                                       20.8910
# 4                                       18.8350
# ..                                          ...
# 403                                     13.7250
# 404                                      6.5650
# 405                                     13.3550
# 406                                     14.0275
# 407                                     13.8810
#
#      IonizationEnergy_composition_average  n_ws^third_composition_average  \
# 0                                  731.00                           1.360
# 1                                  744.50                           1.555
# 2                                  691.90                           1.545
# 3                                  738.20                           1.415
# 4                                  745.15                           1.565
# ..                                    ...                             ...
# 403                                662.00                           1.525
# 404                                710.50                           1.520
# 405                                659.00                           1.465
# 406                                651.00                           1.430
# 407                                684.30                           1.325
#
#      ThermalConductivity_composition_average  \
# 0                                     429.00
# 1                                     264.50
# 2                                     261.35
# 3                                     415.00
# 4                                     254.60
# ..                                       ...
# 403                                    38.20
# 404                                    40.10
# 405                                    22.30
# 406                                    22.85
# 407                                    44.65
#
#      CovalentRadius_composition_average  ...  Site2_MendeleevNumber  \
# 0                                 145.0  ...                     65
# 1                                 135.5  ...                     58
# 2                                 142.0  ...                     49
# 3                                 138.5  ...                     64
# 4                                 138.5  ...                     55
# ..                                  ...  ...                    ...
# 403                               169.5  ...                     47
# 404                               172.5  ...                     48
# 405                               167.5  ...                     43
# 406                               175.0  ...                     45
# 407                               157.0  ...                     80
#
#      Site2_ElasticModulus  Site2_Electronegativity  Site2_AtomicWeight  \
# 0                    80.0                     1.93          107.868200
# 1                   208.0                     1.88           58.933195
# 2                   259.0                     1.66           51.996100
# 3                   124.0                     1.90           63.546000
# 4                   211.0                     1.83           55.845000
# ..                    ...                      ...                 ...
# 403                 104.0                     1.60           92.906380
# 404                 183.0                     1.50          180.947880
# 405                 110.0                     1.54           47.867000
# 406                 139.0                     1.30          178.490000
# 407                  50.0                     1.96          118.710000
#
#      Site2_HeatFusion  Site2_SpecificHeatCapacity  Site2_AtomicRadii  \
# 0               11.30                       0.235              1.444
# 1               16.20                       0.421              1.253
# 2               21.00                       0.449              1.249
# 3               13.60                       0.385              1.278
# 4               13.81                       0.449              1.241
# ..                ...                         ...                ...
# 403             30.00                       0.265              1.429
# 404             36.57                       0.140              1.430
# 405             14.15                       0.523              1.448
# 406             27.20                       0.140              1.564
# 407              7.15                       0.228              1.620
#
#      Site2_ThermalExpansionCoefficient  Site2_BCCefflatcnt  Site2_AtomicVolume
# 0                                 18.9            6.375951           17.075648
# 1                                 13.0            5.507318           10.995861
# 2                                  4.9            5.632801           12.092937
# 3                                 16.5            5.617632           11.829942
# 4                                 11.8            5.557847           11.777365
# ..                                 ...                 ...                 ...
# 403                                7.3            6.625794           18.002133
# 404                                6.3            6.618497           18.046730
# 405                                8.6            6.458833           17.636317
# 406                                5.9            7.046762           22.268711
# 407                               22.0            7.390589           26.966785
#
# [408 rows x 287 columns]

# %%
# The data contains missing values. Clean the data, which corrects missing values
# and provides some basic analysis of the input data

cleaner = DataCleaning()
X, y = cleaner.evaluate(X=X, 
                        y=y, 
                        method='imputation', 
                        strategy='mean', 
                        savepath=savepath)

# %%
X
# Out:
#      valence_composition_average  phi_composition_average  \
# 0                       3.981108                    4.350
# 1                       3.981108                    4.725
# 2                       3.981108                    4.500
# 3                       3.981108                    4.400
# 4                       3.981108                    4.640
# ..                           ...                      ...
# 403                     4.500000                    3.750
# 404                     4.500000                    3.750
# 405                     4.000000                    3.625
# 406                     4.000000                    3.525
# 407                     4.000000                    3.800
#
#      NdValence_composition_average  MiracleRadius_composition_average  \
# 0                             10.0                              144.0
# 1                              8.5                              134.5
# 2                              7.5                              137.0
# 3                             10.0                              135.0
# 4                              8.0                              134.5
# ..                             ...                                ...
# 403                            3.0                              150.5
# 404                            2.5                              151.5
# 405                            2.0                              150.0
# 406                            2.0                              158.0
# 407                            6.0                              156.5
#
#      GSestFCClatcnt_composition_average  \
# 0                              4.027313
# 1                              3.737485
# 2                              3.788936
# 3                              3.782567
# 4                              3.764269
# ..                                  ...
# 403                            4.350534
# 404                            4.348236
# 405                            4.291886
# 406                            4.494239
# 407                            4.816669
#
#      SecondIonizationEnergy_composition_average  \
# 0                                       21.4900
# 1                                       19.2750
# 2                                       18.9950
# 3                                       20.8910
# 4                                       18.8350
# ..                                          ...
# 403                                     13.7250
# 404                                      6.5650
# 405                                     13.3550
# 406                                     14.0275
# 407                                     13.8810
#
#      IonizationEnergy_composition_average  n_ws^third_composition_average  \
# 0                                  731.00                           1.360
# 1                                  744.50                           1.555
# 2                                  691.90                           1.545
# 3                                  738.20                           1.415
# 4                                  745.15                           1.565
# ..                                    ...                             ...
# 403                                662.00                           1.525
# 404                                710.50                           1.520
# 405                                659.00                           1.465
# 406                                651.00                           1.430
# 407                                684.30                           1.325
#
#      ThermalConductivity_composition_average  \
# 0                                     429.00
# 1                                     264.50
# 2                                     261.35
# 3                                     415.00
# 4                                     254.60
# ..                                       ...
# 403                                    38.20
# 404                                    40.10
# 405                                    22.30
# 406                                    22.85
# 407                                    44.65
#
#      CovalentRadius_composition_average  ...  Site2_MendeleevNumber  \
# 0                                 145.0  ...                   65.0
# 1                                 135.5  ...                   58.0
# 2                                 142.0  ...                   49.0
# 3                                 138.5  ...                   64.0
# 4                                 138.5  ...                   55.0
# ..                                  ...  ...                    ...
# 403                               169.5  ...                   47.0
# 404                               172.5  ...                   48.0
# 405                               167.5  ...                   43.0
# 406                               175.0  ...                   45.0
# 407                               157.0  ...                   80.0
#
#      Site2_ElasticModulus  Site2_Electronegativity  Site2_AtomicWeight  \
# 0                    80.0                     1.93          107.868200
# 1                   208.0                     1.88           58.933195
# 2                   259.0                     1.66           51.996100
# 3                   124.0                     1.90           63.546000
# 4                   211.0                     1.83           55.845000
# ..                    ...                      ...                 ...
# 403                 104.0                     1.60           92.906380
# 404                 183.0                     1.50          180.947880
# 405                 110.0                     1.54           47.867000
# 406                 139.0                     1.30          178.490000
# 407                  50.0                     1.96          118.710000
#
#      Site2_HeatFusion  Site2_SpecificHeatCapacity  Site2_AtomicRadii  \
# 0               11.30                       0.235              1.444
# 1               16.20                       0.421              1.253
# 2               21.00                       0.449              1.249
# 3               13.60                       0.385              1.278
# 4               13.81                       0.449              1.241
# ..                ...                         ...                ...
# 403             30.00                       0.265              1.429
# 404             36.57                       0.140              1.430
# 405             14.15                       0.523              1.448
# 406             27.20                       0.140              1.564
# 407              7.15                       0.228              1.620
#
#      Site2_ThermalExpansionCoefficient  Site2_BCCefflatcnt  Site2_AtomicVolume
# 0                                 18.9            6.375951           17.075648
# 1                                 13.0            5.507318           10.995861
# 2                                  4.9            5.632801           12.092937
# 3                                 16.5            5.617632           11.829942
# 4                                 11.8            5.557847           11.777365
# ..                                 ...                 ...                 ...
# 403                                7.3            6.625794           18.002133
# 404                                6.3            6.618497           18.046730
# 405                                8.6            6.458833           17.636317
# 406                                5.9            7.046762           22.268711
# 407                               22.0            7.390589           26.966785
#
# [408 rows x 287 columns]

# %%
# Preprocess the cleaned data to be normalized

#preprocessor = SklearnPreprocessor(preprocessor='StandardScaler', as_frame=True)
#X = preprocessor.evaluate(X=X, 
#                          savepath=savepath)

preprocessor = MeanStdevScaler(mean=0, stdev=1)
X = preprocessor.fit_transform(X)

# %%
print(X['valence_composition_average'].mean(), X['valence_composition_average'].std())
# Out:
# 2.612289469706251e-16 1.0

# %%
X
# Out:
#      valence_composition_average  phi_composition_average  \
# 0                   3.876616e-16                -0.188044
# 1                   3.876616e-16                 0.401340
# 2                   3.876616e-16                 0.047709
# 3                   3.876616e-16                -0.109460
# 4                   3.876616e-16                 0.267746
# ..                           ...                      ...
# 403                 4.529594e-01                -1.131059
# 404                 4.529594e-01                -1.131059
# 405                 1.649124e-02                -1.327521
# 406                 1.649124e-02                -1.484690
# 407                 1.649124e-02                -1.052475
#
#      NdValence_composition_average  MiracleRadius_composition_average  \
# 0                         1.526651                           0.152672
# 1                         0.993825                          -0.581063
# 2                         0.638608                          -0.387975
# 3                         1.526651                          -0.542445
# 4                         0.816216                          -0.581063
# ..                             ...                                ...
# 403                      -0.959870                           0.654702
# 404                      -1.137479                           0.731937
# 405                      -1.315088                           0.616084
# 406                      -1.315088                           1.233966
# 407                       0.105782                           1.118113
#
#      GSestFCClatcnt_composition_average  \
# 0                             -0.112276
# 1                             -0.938868
# 2                             -0.792129
# 3                             -0.810293
# 4                             -0.862480
# ..                                  ...
# 403                            0.809553
# 404                            0.802997
# 405                            0.642288
# 406                            1.219399
# 407                            2.138972
#
#      SecondIonizationEnergy_composition_average  \
# 0                                      1.350633
# 1                                      0.848052
# 2                                      0.784520
# 3                                      1.214720
# 4                                      0.748216
# ..                                          ...
# 403                                   -0.411238
# 404                                   -2.035835
# 405                                   -0.495191
# 406                                   -0.342601
# 407                                   -0.375842
#
#      IonizationEnergy_composition_average  n_ws^third_composition_average  \
# 0                               -0.048616                       -0.767812
# 1                                0.142057                        0.158312
# 2                               -0.600860                        0.110818
# 3                                0.053076                       -0.506597
# 4                                0.151238                        0.205805
# ..                                    ...                             ...
# 403                             -1.023165                        0.015831
# 404                             -0.338156                       -0.007916
# 405                             -1.065537                       -0.269130
# 406                             -1.178528                       -0.435357
# 407                             -0.708202                       -0.934039
#
#      ThermalConductivity_composition_average  \
# 0                                   3.858846
# 1                                   1.699250
# 2                                   1.657896
# 3                                   3.675050
# 4                                   1.569280
# ..                                       ...
# 403                                -1.271671
# 404                                -1.246727
# 405                                -1.480410
# 406                                -1.473189
# 407                                -1.186994
#
#      CovalentRadius_composition_average  ...  Site2_MendeleevNumber  \
# 0                              0.169038  ...               0.445555
# 1                             -0.568374  ...               0.081045
# 2                             -0.063829  ...              -0.387611
# 3                             -0.335507  ...               0.393482
# 4                             -0.335507  ...              -0.075174
# ..                                  ...  ...                    ...
# 403                            2.070784  ...              -0.491757
# 404                            2.303651  ...              -0.439684
# 405                            1.915540  ...              -0.700048
# 406                            2.497707  ...              -0.595903
# 407                            1.100506  ...               1.226648
#
#      Site2_ElasticModulus  Site2_Electronegativity  Site2_AtomicWeight  \
# 0               -0.578574                 0.295503            0.048064
# 1                0.331357                 0.162105           -0.824720
# 2                0.693908                -0.424847           -0.948446
# 3               -0.265785                 0.215464           -0.742448
# 4                0.352684                 0.028707           -0.879799
# ..                    ...                      ...                 ...
# 403             -0.407962                -0.584924           -0.218789
# 404              0.153636                -0.851720            1.351481
# 405             -0.365309                -0.745002           -1.022091
# 406             -0.159153                -1.385312            1.307643
# 407             -0.791839                 0.375542            0.241433
#
#      Site2_HeatFusion  Site2_SpecificHeatCapacity  Site2_AtomicRadii  \
# 0           -0.637562                   -0.382002          -0.048760
# 1           -0.277377                    0.311258          -1.098431
# 2            0.075456                    0.415620          -1.120413
# 3           -0.468496                    0.177079          -0.961039
# 4           -0.453059                    0.415620          -1.164378
# ..                ...                         ...                ...
# 403          0.737020                   -0.270186          -0.131195
# 404          1.219961                   -0.736087          -0.125700
# 405         -0.428067                    0.691433          -0.026778
# 406          0.531200                   -0.736087           0.610718
# 407         -0.942616                   -0.408093           0.918475
#
#      Site2_ThermalExpansionCoefficient  Site2_BCCefflatcnt  Site2_AtomicVolume
# 0                             0.182911           -0.240464           -0.328259
# 1                            -0.176227           -1.351695           -1.080428
# 2                            -0.669281           -1.191167           -0.944702
# 3                             0.036821           -1.210573           -0.977239
# 4                            -0.249272           -1.287054           -0.983743
# ..                                 ...                 ...                 ...
# 403                          -0.523191            0.079157           -0.213637
# 404                          -0.584062            0.069822           -0.208120
# 405                          -0.444059           -0.134435           -0.258895
# 406                          -0.608410            0.617695            0.314209
# 407                           0.371611            1.057550            0.895438
#
# [408 rows x 287 columns]

# %%
# Define two models and two feature selector types to perform

model1 = SklearnModel(model='KernelRidge', kernel='rbf')
model2 = SklearnModel(model='LinearRegression')
models = [model1, model2]

selector1 = NoSelect()
selector2 = EnsembleModelFeatureSelector(model=SklearnModel(model='RandomForestRegressor'), k_features=10)
selectors = [selector1, selector2]

# %%
# Define and run the case where no data split is performed (full fit)

# splitter = NoSplit()
# splitter.evaluate(X=X,
#                   y=y, 
#                   models=models,
#                   selectors=selectors,
#                   savepath=savepath)

# %%
# Define and run the case where random KFold CV is performed

# splitter = SklearnDataSplitter(splitter='KFold', shuffle=True)
# splitter.evaluate(X=X,
#                   y=y, 
#                   models=models,
#                   selectors=selectors,
#                   savepath=savepath)

# %%
# Define and run the case where leave out twins CV is performed

splitter = LeaveOutTwinCV(cv='KFold', threshold='1')
splitter.evaluate(X=X,
                  y=y, 
                  models=models,
                  selectors=selectors,
                  savepath=savepath)
# Out:
# A
# B
# C
# D
# splits_generator = <class 'sklearn.model_selection._split.KFold'>.split(<class 'pandas.core.frame.DataFrame'>, <class 'pandas.core.series.Series'>)
# E

# %%
import sklearn, pandas, numpy, matplotlib, pymatgen, matminer
print(sklearn.__version__, pandas.__version__, numpy.__version__, matplotlib.__version__, matminer.__version__, pymatgen.__version__)

# %%
# !which python
