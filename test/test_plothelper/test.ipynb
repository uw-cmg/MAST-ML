# %%
        #Loaded from figure.pickle
        
        import matplotlib
        import matplotlib.pyplot as plt
        import numpy as np
        matplotlib.rcParams.update({'font.size': 18})
        smallfont = 0.85*matplotlib.rcParams['font.size']
        plt.figure(figsize=(8,6)) #size in inches
        
                

        sine_x = [-10.000000,-9.500000,-9.000000,-8.500000,-8.000000,
                -7.500000,-7.000000,-6.500000,-6.000000,-5.500000,
                -5.000000,-4.500000,-4.000000,-3.500000,-3.000000,
                -2.500000,-2.000000,-1.500000,-1.000000,-0.500000,
                 0.000000, 0.500000, 1.000000, 1.500000, 2.000000,
                 2.500000, 3.000000, 3.500000, 4.000000, 4.500000,
                 5.000000, 5.500000, 6.000000, 6.500000, 7.000000,
                 7.500000, 8.000000, 8.500000, 9.000000, 9.500000,
                 10.000000,]

        
                

        sine_y = [ 0.544021, 0.075151,-0.412118,-0.798487,-0.989358,
                -0.938000,-0.656987,-0.215120, 0.279415, 0.705540,
                 0.958924, 0.977530, 0.756802, 0.350783,-0.141120,
                -0.598472,-0.909297,-0.997495,-0.841471,-0.479426,
                 0.000000, 0.479426, 0.841471, 0.997495, 0.909297,
                 0.598472, 0.141120,-0.350783,-0.756802,-0.977530,
                -0.958924,-0.705540,-0.279415, 0.215120, 0.656987,
                 0.938000, 0.989358, 0.798487, 0.412118,-0.075151,
                -0.544021,]

        
        plt.plot(sine_x, sine_y, label='sine',
                color='b', linestyle='-', linewidth='1.0',
                marker='None', markersize='6.0', markeredgewidth='0.5',
                markeredgecolor='b', markerfacecolor='b')
        
                

        cosine_x = [-5.000000,-4.000000,-3.000000,-2.000000,-1.000000,
                 0.000000, 1.000000, 2.000000, 3.000000, 4.000000,
                ]

        
                

        cosine_y = [ 0.283662,-0.653644,-0.989992,-0.416147, 0.540302,
                 1.000000, 0.540302,-0.416147,-0.989992,-0.653644,
                ]

        
                

        cosine_x_neg_err = [ 1.200000, 1.200000, 1.200000, 1.200000, 1.200000,
                 1.200000, 1.200000, 1.200000, 1.200000, 1.200000,
                ]

                

        cosine_x_pos_err = [ 0.000000, 0.000000, 0.000000, 0.000000, 0.000000,
                 0.000000, 0.000000, 0.000000, 0.000000, 0.000000,
                ]

                

        cosine_y_neg_err = [-0.500000,-0.400000,-0.300000,-0.200000,-0.100000,
                 0.000000, 0.100000, 0.200000, 0.300000, 0.400000,
                ]

                

        cosine_y_pos_err = [-0.500000,-0.400000,-0.300000,-0.200000,-0.100000,
                -0.000000, 0.100000, 0.200000, 0.300000, 0.400000,
                ]

        
        (_, caps, _)=plt.errorbar(cosine_x, cosine_y, label='cosine',
                xerr=(cosine_x_neg_err,cosine_x_pos_err),
                yerr=(cosine_y_neg_err,cosine_y_pos_err),
                        color='r', linestyle=':', linewidth='3.0',
                marker='s', markersize='15.0', markeredgewidth='2',
                markeredgecolor='darkgreen', markerfacecolor='green')
        
        

        for cap in caps:
            cap.set_color('r')
            cap.set_markeredgewidth('2')
        
        
                

        cosine_series2_x = [-8.000000,-7.000000,-6.000000,-5.000000,-4.000000,
                -3.000000,-2.000000,-1.000000, 0.000000, 1.000000,
                ]

        
                

        cosine_series2_y = [ 0.783662,-0.153644,-0.489992, 0.083853, 1.040302,
                 1.500000, 1.040302, 0.083853,-0.489992,-0.153644,
                ]

        
                

        cosine_series2_y_neg_err = [ 0.200000, 0.200000, 0.200000, 0.200000, 0.200000,
                 0.200000, 0.200000, 0.200000, 0.200000, 0.200000,
                ]

                

        cosine_series2_y_pos_err = [ 0.500000, 0.500000, 0.500000, 0.500000, 0.500000,
                 0.500000, 0.500000, 0.500000, 0.500000, 0.500000,
                ]

        
        (_, caps, _)=plt.errorbar(cosine_series2_x, cosine_series2_y, label='cosine_series2',
        #
                yerr=(cosine_series2_y_neg_err,cosine_series2_y_pos_err),
                        color='gray', linestyle='--', linewidth='2.0',
                marker='o', markersize='10.0', markeredgewidth='1',
                markeredgecolor='black', markerfacecolor='blue')
        
        

        for cap in caps:
            cap.set_color('gray')
            cap.set_markeredgewidth('1')
        
        
        plt.xlabel('Number')
        plt.ylabel('Function value')
        ax = plt.gca()
        #ax.margins(0.5,0.5) #set margins so points are not cut off
        #ax.set_xscale('log', nonposx='clip') #set log scale
        ax.set_xticks([-10.0, -5.0, 0.0, 5.0, 10.0])
        #ax.set_xticklabels(["a","b","c","d","e"],rotation=90) #set tick labels
        ax.set_yticks([-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
        #
        ### Set additional dashed gridline at x=0
        #ax.set_xticks(np.array([0]),minor=True)
        #ax.xaxis.grid(which='minor', linestyle='--')
        #
        ### Do not use scientific ticks with an automatic multiplier
        #y_formatter = matplotlib.ticker.ScalarFormatter()
        #y_formatter.set_useOffset(False)
        #y_formatter.set_scientific(False)
        #ax.yaxis.set_major_formatter(y_formatter)
        #
        
        
                
        plt.annotate("Annotations:", 
                    xy=(0.05, 0.88), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("  sine-type curves", 
                    xy=(0.05, 0.81), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("-0.416", 
                    xy=(2, -0.41614683654714241), xycoords='data',
                    fontsize=smallfont)

                                
        plt.annotate("-0.990", 
                    xy=(3, -0.98999249660044542), xycoords='data',
                    fontsize=smallfont)

                                
        plt.annotate("-0.654", 
                    xy=(4, -0.65364362086361194), xycoords='data',
                    fontsize=smallfont)

                
        
        lgd = plt.legend(loc='lower center', #location
                        ncol=2, #number of columns
                        numpoints=1, #number of points
                        bbox_to_anchor=(0.5,1), #anchor against the figure axes; this anchor pins the lower center point to x=half axis and y=full axis
                        fontsize=smallfont,
                        )
        lgd.get_frame().set_alpha(0.5) #translucent legend
        
        plt.savefig("notebook_figure.png", bbox_inches="tight")
        plt.show()
