# %%
        #Loaded from per_group_info.pickle
        
        import matplotlib
        import matplotlib.pyplot as plt
        import numpy as np
        from numpy import array
        from numpy import nan
        matplotlib.rcParams.update({'font.size': 18})
        smallfont = 0.85*matplotlib.rcParams['font.size']
        plt.figure(figsize=(8,6)) #size in inches
        
                

        All_others_x = array([ -1.04316039e+00,  -1.02442396e+00,  -9.82578264e-01,
        -9.63355893e-01,  -9.57630814e-01,  -9.38113038e-01,
        -8.69356071e-01,  -7.84805986e-01,  -7.73024760e-01,
        -7.38534516e-01,  -7.11017095e-01,  -6.66636957e-01,
        -5.90146050e-01,  -4.28451077e-01,  -4.08465986e-01,
        -6.41810554e-02,  -2.42124246e-02,  -1.64509605e-02,
        -7.32919383e-04,   2.94531755e-02,   4.82957120e-02,
         6.92392466e-02,   1.14841507e-01,   1.37247090e-01,
         2.89544051e-01,   2.97150869e-01,   3.95942433e-01,
         3.99705891e-01,   4.06760584e-01,   4.21962496e-01,
         4.26132559e-01,   4.65116877e-01,   4.68568494e-01,
         6.61095543e-01,   7.03079514e-01,   7.23528442e-01,
         7.78537438e-01,   7.91724007e-01,   8.00279560e-01,
         8.09854865e-01,   8.51814759e-01,   8.54180155e-01,
         8.67358990e-01,   8.95788151e-01,   9.39586336e-01,
         9.52101677e-01,   9.77419638e-01,   9.91359821e-01,
         9.94321640e-01,   9.96064707e-01,   1.00065493e+00,
         1.00733990e+00,   1.01810760e+00,   1.03268991e+00,
         1.05335323e+00,   1.05902784e+00,   1.08406074e+00,
         1.12348776e+00,   1.19154421e+00])

        
                

        All_others_y = array([-0.9613449 , -0.9649216 , -0.90650714, -0.92231996, -0.87620715,
       -0.88411308, -0.93506303, -0.73952288, -0.73970952, -0.74339138,
       -0.68611514, -0.74926807, -0.44467118, -0.44144662, -0.44806242,
       -0.04453977,  0.00835039, -0.04949139, -0.09226491,  0.01759369,
        0.02859483,  0.06539437,  0.36618136,  0.28390387,  0.35429196,
        0.3635863 ,  0.4032638 ,  0.36648383,  0.36529578,  0.3419452 ,
        0.37676163,  0.45706558,  0.33637468,  0.69287016,  0.70057938,
        0.71179669,  0.7010497 ,  0.7148889 ,  0.74994657,  0.70301123,
        0.93798937,  0.89820856,  0.71940242,  0.98182672,  0.95343936,
        0.92213449,  0.94284137,  0.95375965,  1.0506733 ,  0.8851462 ,
        0.93305513,  0.91891742,  1.02147894,  1.05338795,  0.98948192,
        1.02425995,  1.0265779 ,  0.9980292 ,  1.07940783])

        
                

        All_others_x_neg_err = array([ 0.08698082,  0.08701521,  0.09391995,  0.0940468 ,  0.07989568,
        0.08005807,  0.08680432,  0.10070803,  0.10069158,  0.1008379 ,
        0.07359654,  0.10076784,  0.10758375,  0.10750948,  0.10763018,
        0.11445675,  0.00491732,  0.11452758,  0.11408528,  0.16890093,
        0.16895896,  0.00530267,  0.16228531,  0.12125616,  0.05295335,
        0.12112842,  0.16193355,  0.01222851,  0.16248601,  0.05287425,
        0.01201141,  0.0120541 ,  0.12098784,  0.04605888,  0.15513716,
        0.12793162,  0.15545124,  0.04598511,  0.01921798,  0.15501087,
        0.14836151,  0.0259119 ,  0.12798945,  0.13503329,  0.14835674,
        0.02580167,  0.1486735 ,  0.03918322,  0.14177345,  0.02604268,
        0.03901473,  0.03928718,  0.03254918,  0.14131827,  0.13490351,
        0.03247515,  0.03256535,  0.1347413 ,  0.14171234])

                

        All_others_x_pos_err = array([ 0.08698082,  0.08701521,  0.09391995,  0.0940468 ,  0.07989568,
        0.08005807,  0.08680432,  0.10070803,  0.10069158,  0.1008379 ,
        0.07359654,  0.10076784,  0.10758375,  0.10750948,  0.10763018,
        0.11445675,  0.00491732,  0.11452758,  0.11408528,  0.16890093,
        0.16895896,  0.00530267,  0.16228531,  0.12125616,  0.05295335,
        0.12112842,  0.16193355,  0.01222851,  0.16248601,  0.05287425,
        0.01201141,  0.0120541 ,  0.12098784,  0.04605888,  0.15513716,
        0.12793162,  0.15545124,  0.04598511,  0.01921798,  0.15501087,
        0.14836151,  0.0259119 ,  0.12798945,  0.13503329,  0.14835674,
        0.02580167,  0.1486735 ,  0.03918322,  0.14177345,  0.02604268,
        0.03901473,  0.03928718,  0.03254918,  0.14131827,  0.13490351,
        0.03247515,  0.03256535,  0.1347413 ,  0.14171234])

        
        (_, caps, _)=plt.errorbar(All_others_x, All_others_y, label='All others',
                xerr=(All_others_x_neg_err,All_others_x_pos_err),
        #
                        color='#8B0000', linestyle='None', linewidth='2.0',
                marker='o', markersize='15.0', markeredgewidth='2',
                markeredgecolor='#8B0000', markerfacecolor='red')
        
        

        for cap in caps:
            cap.set_color('#8B0000')
            cap.set_markeredgewidth('2')
        
        
                

        A_x = array([-0.84434504, -0.80029786, -0.77218399, -0.51158776, -0.26284732,
       -0.16456991, -0.02789832,  0.042534  ,  0.33209982,  0.33898014,
        0.46269375,  0.54054872,  0.56610728,  0.60140289,  0.67792216,
        0.73164988,  0.95006785,  1.04225576])

        
                

        A_y = array([-0.89650594, -0.93117596, -0.85534887, -0.57808958, -0.28534117,
       -0.03873822, -0.07770972,  0.03306209,  0.34328491,  0.33124178,
        0.73026456,  0.37258418,  0.62474683,  0.71577728,  0.72008569,
        0.76189144,  0.95060765,  1.08237966])

        
                

        A_x_neg_err = array([ 0.09404116,  0.08728558,  0.08024374,  0.07351386,  0.06655173,
        0.05986516,  0.11449521,  0.05992605,  0.05291789,  0.05283949,
        0.12786247,  0.1620551 ,  0.01876767,  0.04588113,  0.01843789,
        0.01876071,  0.14817075,  0.14176494])

                

        A_x_pos_err = array([ 0.09404116,  0.08728558,  0.08024374,  0.07351386,  0.06655173,
        0.05986516,  0.11449521,  0.05992605,  0.05291789,  0.05283949,
        0.12786247,  0.1620551 ,  0.01876767,  0.04588113,  0.01843789,
        0.01876071,  0.14817075,  0.14176494])

        
        (_, caps, _)=plt.errorbar(A_x, A_y, label='A',
                xerr=(A_x_neg_err,A_x_pos_err),
        #
                        color='#00008B', linestyle='None', linewidth='2.0',
                marker='o', markersize='10.0', markeredgewidth='2',
                markeredgecolor='#00008B', markerfacecolor='blue')
        
        

        for cap in caps:
            cap.set_color('#00008B')
            cap.set_markeredgewidth('2')
        
        
                

        B_x = array([-0.87772767, -0.87181554, -0.7378923 , -0.67932324, -0.57503316,
       -0.42654079, -0.41363869, -0.36829637, -0.08551171, -0.05545447,
       -0.05014082,  0.05508093,  0.1468898 ,  0.23408484,  0.25375939,
        0.30378172,  0.57017569,  0.61359703,  0.72219784,  0.86385458,
        0.93191171,  0.95051635,  1.03270284])

        
                

        B_y = array([-0.93199782, -0.83616934, -0.76912923, -0.71182972, -0.48427509,
       -0.43746601, -0.36089722, -0.36087088,  0.0167736 , -0.00344047,
        0.00456786, -0.01085955,  0.06382097, -0.04213207,  0.29660782,
        0.35485974,  0.6763312 ,  0.71295206,  1.02650581,  0.72837941,
        0.99618696,  0.91238843,  0.96937684])

        
                

        B_x_neg_err = array([ 0.09375779,  0.07997051,  0.07352763,  0.07373494,  0.06655922,
        0.10772465,  0.06672434,  0.06656144,  0.16909729,  0.05984693,
        0.00519446,  0.00568703,  0.16858382,  0.05966676,  0.01211105,
        0.12147004,  0.04614595,  0.15525206,  0.0324436 ,  0.12792874,
        0.13468027,  0.02574833,  0.03937554])

                

        B_x_pos_err = array([ 0.09375779,  0.07997051,  0.07352763,  0.07373494,  0.06655922,
        0.10772465,  0.06672434,  0.06656144,  0.16909729,  0.05984693,
        0.00519446,  0.00568703,  0.16858382,  0.05966676,  0.01211105,
        0.12147004,  0.04614595,  0.15525206,  0.0324436 ,  0.12792874,
        0.13468027,  0.02574833,  0.03937554])

        
        (_, caps, _)=plt.errorbar(B_x, B_y, label='B',
                xerr=(B_x_neg_err,B_x_pos_err),
        #
                        color='#004400', linestyle='None', linewidth='2.0',
                marker='s', markersize='8.0', markeredgewidth='2',
                markeredgecolor='#004400', markerfacecolor='green')
        
        

        for cap in caps:
            cap.set_color('#004400')
            cap.set_markeredgewidth('2')
        
        
                

        _line9_x = array([-1.5,  1.5])

        
                

        _line9_y = array([-1.5,  1.5])

        
        plt.plot(_line9_x, _line9_y, label='_line9',
                color='.3', linestyle='--', linewidth='1.0',
                marker='None', markersize='6.0', markeredgewidth='0.5',
                markeredgecolor='.3', markerfacecolor='.3')
        
        plt.xlabel('Initial dataset measured')
        plt.ylabel('Initial dataset predicted')
        ax = plt.gca()
        #ax.margins(0.5,0.5) #set margins so points are not cut off
        #ax.set_xscale('log', nonposx='clip') #set log scale
        #ax.set_xlim([-10.0, 10.0]) #set limits on x axis. Similar for y axis.
        ax.set_xticks([-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5])
        ax.set_xticklabels(['−1.5', '−1.0', '−0.5', '0.0', '0.5', '1.0', '1.5'], rotation=0.0)
        ax.set_yticks([-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5])
        #
        ### Set additional dashed gridline at x=0
        #ax.set_xticks(np.array([0]),minor=True)
        #ax.xaxis.grid(which='minor', linestyle='--')
        #
        ### Add diagonal guideline
        #plt.plot([-10,10],[-10,10],'--', color='gray')
        #
        ### Do not use scientific ticks with an automatic multiplier
        #y_formatter = matplotlib.ticker.ScalarFormatter()
        #y_formatter.set_useOffset(False)
        #y_formatter.set_scientific(False)
        #ax.yaxis.set_major_formatter(y_formatter)
        #
        ### Set xticks as times
        #import time
        #my_xticks = ax.get_xticks()
        #adjusted_xticks = list()
        #for tidx in range(0, len(my_xticks)):
        #    mytick = time.strftime("format string", time.localtime(my_xticks[tidx]))
        #               #see time.strftime for format strings to use
        #    adjusted_xticks.append(mytick)
        #    ax.set_xticklabels(adjusted_xticks, rotation=90.0)
        #
        ### Use a second y axis with the same x axis
        #ax2 = ax.twinx()
        #ax2.set_ylabel("second label")
        #ax2.plot(...) #line on second axis, for example, cut a plt.plot section
        #              #from above and paste it here, making it ax2.plot
        #ax2.errorbar(...) #line with errorbar on second axis, for example, cut
        #                  # a plt.errorbar section from above, making it
        #                  # (_, caps, _)=ax2.errorbar(...)
        #ax2.legend() #legend for entries on second axis. 
        
        
                
        plt.annotate("RMSEs for overall fit:", 
                    xy=(0.05, 0.88), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("Overall: 0.088", 
                    xy=(0.05, 0.81), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("A: 0.10", 
                    xy=(0.05, 0.74), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("B: 0.11", 
                    xy=(0.05, 0.6699999999999999), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("All others: 0.08", 
                    xy=(0.05, 0.5999999999999999), xycoords='axes fraction',
                    fontsize=smallfont)

                
        
        lgd = ax.legend(loc='lower center', #location
                        ncol=2, #number of columns
                        numpoints=1, #number of points
                        bbox_to_anchor=(0.5,1), #anchor against the figure axes; this anchor pins the lower center point to x=half axis and y=full axis
                        fontsize=smallfont,
                        )
        if not (lgd is None): #lgd is None if there are no labeled lines
            lgd.get_frame().set_alpha(0.5) #translucent legend
        
        plt.savefig("per_group_info_nb", bbox_inches="tight")
        plt.show()
