# %%
        #Loaded from loo_results.pickle
        
        import matplotlib
        import matplotlib.pyplot as plt
        import numpy as np
        from numpy import array
        matplotlib.rcParams.update({'font.size': 18})
        smallfont = 0.85*matplotlib.rcParams['font.size']
        plt.figure(figsize=(8,6)) #size in inches
        
                

        loo_prediction_x = array([ -1.04316039e+00,  -1.02442396e+00,  -9.82578264e-01,
        -9.63355893e-01,  -9.57630814e-01,  -9.38113038e-01,
        -8.77727665e-01,  -8.71815543e-01,  -8.69356071e-01,
        -8.44345039e-01,  -8.00297857e-01,  -7.84805986e-01,
        -7.73024760e-01,  -7.72183986e-01,  -7.38534516e-01,
        -7.37892295e-01,  -7.11017095e-01,  -6.79323237e-01,
        -6.66636957e-01,  -5.90146050e-01,  -5.75033164e-01,
        -5.11587755e-01,  -4.28451077e-01,  -4.26540792e-01,
        -4.13638685e-01,  -4.08465986e-01,  -3.68296375e-01,
        -2.62847318e-01,  -1.64569908e-01,  -8.55117121e-02,
        -6.41810554e-02,  -5.54544749e-02,  -5.01408153e-02,
        -2.78983173e-02,  -2.42124246e-02,  -1.64509605e-02,
        -7.32919383e-04,   2.94531755e-02,   4.25340034e-02,
         4.82957120e-02,   5.50809275e-02,   6.92392466e-02,
         1.14841507e-01,   1.37247090e-01,   1.46889796e-01,
         2.34084838e-01,   2.53759391e-01,   2.89544051e-01,
         2.97150869e-01,   3.03781723e-01,   3.32099818e-01,
         3.38980141e-01,   3.95942433e-01,   3.99705891e-01,
         4.06760584e-01,   4.21962496e-01,   4.26132559e-01,
         4.62693745e-01,   4.65116877e-01,   4.68568494e-01,
         5.40548719e-01,   5.66107276e-01,   5.70175690e-01,
         6.01402894e-01,   6.13597034e-01,   6.61095543e-01,
         6.77922160e-01,   7.03079514e-01,   7.22197837e-01,
         7.23528442e-01,   7.31649878e-01,   7.78537438e-01,
         7.91724007e-01,   8.00279560e-01,   8.09854865e-01,
         8.51814759e-01,   8.54180155e-01,   8.63854583e-01,
         8.67358990e-01,   8.95788151e-01,   9.31911708e-01,
         9.39586336e-01,   9.50067847e-01,   9.50516350e-01,
         9.52101677e-01,   9.77419638e-01,   9.91359821e-01,
         9.94321640e-01,   9.96064707e-01,   1.00065493e+00,
         1.00733990e+00,   1.01810760e+00,   1.03268991e+00,
         1.03270284e+00,   1.04225576e+00,   1.05335323e+00,
         1.05902784e+00,   1.08406074e+00,   1.12348776e+00,
         1.19154421e+00])

        
                

        loo_prediction_y = array([-0.94088365, -0.94656218, -0.89284435, -0.91301646, -0.85773145,
       -0.86642225, -0.95227463, -0.80797329, -0.95245373, -0.90878265,
       -0.97542448, -0.70406526, -0.72715606, -0.87374124, -0.7442942 ,
                

        loo_prediction_x_pos_err = array([ 0.08698082,  0.08701521,  0.09391995,  0.0940468 ,  0.07989568,
        0.08005807,  0.09375779,  0.07997051,  0.08680432,  0.09404116,
        0.08728558,  0.10070803,  0.10069158,  0.08024374,  0.1008379 ,
        0.07352763,  0.07359654,  0.07373494,  0.10076784,  0.10758375,
        0.06655922,  0.07351386,  0.10750948,  0.10772465,  0.06672434,
        0.10763018,  0.06656144,  0.06655173,  0.05986516,  0.16909729,
        0.11445675,  0.05984693,  0.00519446,  0.11449521,  0.00491732,
        0.11452758,  0.11408528,  0.16890093,  0.05992605,  0.16895896,
        0.00568703,  0.00530267,  0.16228531,  0.12125616,  0.16858382,
        0.05966676,  0.01211105,  0.05295335,  0.12112842,  0.12147004,
        0.05291789,  0.05283949,  0.16193355,  0.01222851,  0.16248601,
        0.05287425,  0.01201141,  0.12786247,  0.0120541 ,  0.12098784,
        0.1620551 ,  0.01876767,  0.04614595,  0.04588113,  0.15525206,
        0.04605888,  0.01843789,  0.15513716,  0.0324436 ,  0.12793162,
        0.01876071,  0.15545124,  0.04598511,  0.01921798,  0.15501087,
        0.14836151,  0.0259119 ,  0.12792874,  0.12798945,  0.13503329,
        0.13468027,  0.14835674,  0.14817075,  0.02574833,  0.02580167,
        0.1486735 ,  0.03918322,  0.14177345,  0.02604268,  0.03901473,
        0.03928718,  0.03254918,  0.14131827,  0.03937554,  0.14176494,
        0.13490351,  0.03247515,  0.03256535,  0.1347413 ,  0.14171234])

        
        (_, caps, _)=plt.errorbar(loo_prediction_x, loo_prediction_y, label='loo_prediction',
                xerr=(loo_prediction_x_neg_err,loo_prediction_x_pos_err),
        #
                        color='#8B0000', linestyle='None', linewidth='2.0',
                marker='o', markersize='15.0', markeredgewidth='2',
                markeredgecolor='#8B0000', markerfacecolor='red')
        
        

        for cap in caps:
            cap.set_color('#8B0000')
            cap.set_markeredgewidth('2')
        
        
                

        _line3_x = array([-1.5,  1.5])

        
                

        _line3_y = array([-1.5,  1.5])

        
        plt.plot(_line3_x, _line3_y, label='_line3',
                color='.3', linestyle='--', linewidth='1.0',
                marker='None', markersize='6.0', markeredgewidth='0.5',
                markeredgecolor='.3', markerfacecolor='.3')
        
        plt.xlabel('Measured')
        plt.ylabel('Predicted')
        ax = plt.gca()
        #ax.margins(0.5,0.5) #set margins so points are not cut off
        #ax.set_xscale('log', nonposx='clip') #set log scale
        #ax.set_xlim([-10.0, 10.0]) #set limits on x axis. Similar for y axis.
        ax.set_xticks([-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5])
        #ax.set_xticklabels(["a","b","c","d","e"],rotation=90) #set tick labels
        ax.set_yticks([-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5])
        #
        ### Set additional dashed gridline at x=0
        #ax.set_xticks(np.array([0]),minor=True)
        #ax.xaxis.grid(which='minor', linestyle='--')
        #
        ### Add diagonal guideline
        #plt.plot([-10,10],[-10,10],'--', color='gray')
        #
        ### Do not use scientific ticks with an automatic multiplier
        #y_formatter = matplotlib.ticker.ScalarFormatter()
        #y_formatter.set_useOffset(False)
        #y_formatter.set_scientific(False)
        #ax.yaxis.set_major_formatter(y_formatter)
        #
        ### Set xticks as times
        #import time
        #my_xticks = ax.get_xticks()
        #adjusted_xticks = list()
        #for tidx in range(0, len(my_xticks)):
        #    mytick = time.strftime("format string", time.localtime(my_xticks[tidx]))
        #               #see time.strftime for format strings to use
        #    adjusted_xticks.append(mytick)
        #    ax.set_xticklabels(adjusted_xticks, rotation=90.0)
        #
        ### Use a second y axis with the same x axis
        #ax2 = ax.twinx()
        #ax2.set_ylabel("second label")
        #ax2.plot(...) #line on second axis, for example, cut a plt.plot section
        #              #from above and paste it here, making it ax2.plot
        #ax2.errorbar(...) #line with errorbar on second axis, for example, cut
        #                  # a plt.errorbar section from above, making it
        #                  # (_, caps, _)=ax2.errorbar(...)
        #ax2.legend() #legend for entries on second axis. 
        
        
                
        plt.annotate("Mean over 100 LOO tests:", 
                    xy=(0.05, 0.88), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("RMSE:", 
                    xy=(0.05, 0.81), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("    0.09 $\pm$ 0.08", 
                    xy=(0.05, 0.74), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("Mean error:", 
                    xy=(0.05, 0.6699999999999999), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("    -0.00 $\pm$ 0.12", 
                    xy=(0.05, 0.5999999999999999), xycoords='axes fraction',
                    fontsize=smallfont)

                                
        plt.annotate("B", 
                    xy=(0.72219783712966312, 1.0958644481784137), xycoords='data',
                    fontsize=smallfont)

                                
        plt.annotate("B", 
                    xy=(0.23408483791585949, -0.10568619451298124), xycoords='data',
                    fontsize=smallfont)

                                
        plt.annotate("A", 
                    xy=(0.46269374546995939, 0.79527829617351742), xycoords='data',
                    fontsize=smallfont)

                
        
        lgd = ax.legend(loc='lower center', #location
                        ncol=2, #number of columns
                        numpoints=1, #number of points
                        bbox_to_anchor=(0.5,1), #anchor against the figure axes; this anchor pins the lower center point to x=half axis and y=full axis
                        fontsize=smallfont,
                        )
        if not (lgd is None): #lgd is None if there are no labeled lines
            lgd.get_frame().set_alpha(0.5) #translucent legend
        
        plt.savefig("loo_results_nb", bbox_inches="tight")
        plt.show()
