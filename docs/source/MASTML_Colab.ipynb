# %%
# pip install mastml and pinned versions of few dependencies. It will take a couple minutes
# Don't worry about the package incompatability warnings
# !pip install mastml
# !pip install mdf_toolbox --upgrade
# !pip install scikit-learn=='0.23.2'
# Out:
# Collecting mastml
#   Downloading https://files.pythonhosted.org/packages/d9/c9/0c0bf235f469b782f313a2318191452aae885c517593869795706789fd7f/mastml-2.0.14-py3-none-any.whl (233kB)
#      |████████████████████████████████| 235kB 7.8MB/s
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.10.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.6/dist-packages (from mastml) (3.4.0)
# Collecting configobj>=5.0.6
#   Downloading https://files.pythonhosted.org/packages/64/61/079eb60459c44929e684fa7d9e2fdca403f67d64dd9dbac27296be2e0fab/configobj-5.0.6.tar.gz
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.8.1)
# Requirement already satisfied: ipython-genutils>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.2.0)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.17.4)
# Collecting duecredit
#   Downloading https://files.pythonhosted.org/packages/56/07/de31665385ded5d7e234deb7226d15b6134e49a7da2c57086fb1cf363dfa/duecredit-0.8.0.tar.gz (68kB)
#      |████████████████████████████████| 71kB 5.3MB/s
# Collecting dominate>=2.3.5
#   Downloading https://files.pythonhosted.org/packages/ef/a8/4354f8122c39e35516a2708746d89db5e339c867abbd8e0179bccee4b7f9/dominate-2.6.0-py2.py3-none-any.whl
# Requirement already satisfied: atomicwrites in /usr/local/lib/python3.6/dist-packages (from mastml) (1.4.0)
# Collecting globus-nexus-client
#   Downloading https://files.pythonhosted.org/packages/58/e0/8f70b507d846c19fbc63236e5d5464a1856045a7508f1017f620f5314551/globus_nexus_client-0.2.9-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2018.4.16 in /usr/local/lib/python3.6/dist-packages (from mastml) (2020.12.5)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.10.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.6/dist-packages (from mastml) (3.3.0)
# Collecting pytest>=5.0.1
#   Downloading https://files.pythonhosted.org/packages/d7/15/5ef931cbd22585865aad0ea025162545b53af9319cf38542e0b7981d5b34/pytest-6.2.1-py3-none-any.whl (279kB)
#      |████████████████████████████████| 286kB 12.1MB/s
# Collecting ruamel.yaml>=0.15.42
#   Downloading https://files.pythonhosted.org/packages/7e/39/186f14f3836ac5d2a6a042c8de69988770e8b9abb537610edc429e4914aa/ruamel.yaml-0.16.12-py2.py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 15.3MB/s
# Requirement already satisfied: jdcal in /usr/local/lib/python3.6/dist-packages (from mastml) (1.4.1)
# Collecting sympy>=1.2
#   Downloading https://files.pythonhosted.org/packages/ff/69/b16fc81b939d3efdd0b552f2e3e54f7fa1423d0c320cced2e69e675dde26/sympy-1.7.1-py3-none-any.whl (5.9MB)
#      |████████████████████████████████| 5.9MB 12.1MB/s
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from mastml) (0.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.4.7)
# Collecting dlhub-sdk>=0.9.3
#   Downloading https://files.pythonhosted.org/packages/1e/cd/02ad247cf7df4467b63dec57e2c8d8f5fe64330bf6da61e6ac6cddcde149/dlhub_sdk-0.9.4-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 6.7MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (4.4.2)
# Requirement already satisfied: pymongo>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (3.11.2)
# Collecting matminer>=0.6.3
#   Downloading https://files.pythonhosted.org/packages/2a/c1/8a933de6c45387c2956dc29be41a98e70102c9497eed7cdc71368e00c541/matminer-0.6.4.tar.gz (5.7MB)
#      |████████████████████████████████| 5.7MB 45.8MB/s
# Collecting sphinx-automodapi
#   Downloading https://files.pythonhosted.org/packages/16/08/83a3ee2cd420043538d195f024caac76dc2567a266361d95bb9344ab5594/sphinx_automodapi-0.13-py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 6.3MB/s
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.6/dist-packages (from mastml) (3.0.4)
# Requirement already satisfied: keras>=2.2.4 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.4.3)
# Collecting PyDispatcher>=2.0.5
#   Downloading https://files.pythonhosted.org/packages/cd/37/39aca520918ce1935bea9c356bcbb7ed7e52ad4e31bff9b943dfc8e7115b/PyDispatcher-2.0.5.tar.gz
# Collecting pluggy>=0.12
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Collecting scikit-optimize>=0.5.2
#   Downloading https://files.pythonhosted.org/packages/8b/03/be33e89f55866065a02e515c5b319304a801a9f1027a9b311a9b1d1f8dc7/scikit_optimize-0.8.1-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 11.1MB/s
# Collecting forestci>=0.4.1
#   Downloading https://files.pythonhosted.org/packages/00/ea/a0236979a5121d0277ff74c6cb1dc88f8761565ca3647cc76277f900e2f0/forestci-0.4.1-py3-none-any.whl
# Collecting jsonschema>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 7.4MB/s
# Collecting cryptography
#   Downloading https://files.pythonhosted.org/packages/c9/de/7054df0620b5411ba45480f0261e1fb66a53f3db31b28e3aa52c026e72d9/cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6MB)
#      |████████████████████████████████| 2.6MB 44.1MB/s
# Collecting mlxtend>=0.17.2
#   Downloading https://files.pythonhosted.org/packages/86/30/781c0b962a70848db83339567ecab656638c62f05adb064cb33c0ae49244/mlxtend-0.18.0-py2.py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.4MB 24.7MB/s
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.5)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.4.1)
# Collecting spglib>=1.10.3.65
#   Downloading https://files.pythonhosted.org/packages/22/16/efc10f7611f94de5503c4f33c216b73bcf99688382e9b9855f5442973b90/spglib-1.16.0-cp36-cp36m-manylinux2010_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 44.9MB/s
# Collecting xlsxwriter>=1.3.7
#   Downloading https://files.pythonhosted.org/packages/6b/41/bf1aae04932d1eaffee1fc5f8b38ca47bbbf07d765129539bc4bcce1ce0c/XlsxWriter-1.3.7-py2.py3-none-any.whl (144kB)
#      |████████████████████████████████| 153kB 57.8MB/s
# Collecting jwt
#   Downloading https://files.pythonhosted.org/packages/64/bd/ba8a9b250dc59b62fbc8e020f83246dbddf15a5bfb2ccef8554e443bee7b/jwt-1.1.0-py3-none-any.whl
# Collecting mdf-forge>=0.6.1J
#   Downloading https://files.pythonhosted.org/packages/6f/0c/697e48caaabc83e071c222dc6d25ec0a924c69d4cf8f990964f47091b8d2/mdf_forge-0.7.6-py2.py3-none-any.whl
# Requirement already satisfied: palettable>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (3.3.0)
# Collecting mdf-toolbox==0.5.1
#   Downloading https://files.pythonhosted.org/packages/64/99/65058037a394889dbb274d30d237902bc4611cf7a5ef53c9b60501e4a35d/mdf_toolbox-0.5.1-py2.py3-none-any.whl
# Collecting plotly>=4.5.0
#   Downloading https://files.pythonhosted.org/packages/1f/f6/bd3c17c8003b6641df1228e80e1acac97ed8402635e46c2571f8e1ef63af/plotly-4.14.3-py2.py3-none-any.whl (13.2MB)
#      |████████████████████████████████| 13.2MB 36.6MB/s
# Collecting monty>=1.0.2
#   Downloading https://files.pythonhosted.org/packages/eb/ce/fb3da79f73d6f914204af8fd4965ad32b23097baf33c1b709e32a1bfae3f/monty-4.0.2-py3-none-any.whl (62kB)
#      |████████████████████████████████| 71kB 6.8MB/s
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (20.3.0)
# Collecting scikit-learn>=0.23.1
#   Downloading https://files.pythonhosted.org/packages/30/aa/db462d385c56905b731403885454188683f63c86ea68900f6f7e7558b5fa/scikit_learn-0.24.0-cp36-cp36m-manylinux2010_x86_64.whl (22.2MB)
#      |████████████████████████████████| 22.2MB 1.6MB/s
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.19.5)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from mastml) (5.0.8)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.6/dist-packages (from mastml) (2.5.9)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.6/dist-packages (from mastml) (4.3.3)
# Collecting aflow
#   Downloading https://files.pythonhosted.org/packages/cc/96/c2d43ec7176f4ce83f3bbce4dada5f27d83ba81be1857fba77dcf5b5a439/aflow-0.0.11-py3-none-any.whl
# Requirement already satisfied: pytz>=2018.5 in /usr/local/lib/python3.6/dist-packages (from mastml) (2018.9)
# Requirement already satisfied: Cython>=0.29.13 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.29.21)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.4.1)
# Collecting psutil>=5.5.1
#   Downloading https://files.pythonhosted.org/packages/da/82/56cd16a4c5f53e3e5dd7b2c30d5c803e124f218ebb644ca9c30bc907eadd/psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291kB)
#      |████████████████████████████████| 296kB 35.5MB/s
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.23.0)
# Collecting citeproc-py>=0.4
#   Downloading https://files.pythonhosted.org/packages/a2/a2/b202f24040ac601cbdcca10d169558c5339ef0ec3ce95894e6bf1c72caa5/citeproc_py-0.5.1-py2.py3-none-any.whl (173kB)
#      |████████████████████████████████| 174kB 36.3MB/s
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.16.0)
# Requirement already satisfied: urllib3<1.25,>=1.24.2 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.24.3)
# Requirement already satisfied: tensorflow>=1.13.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (2.4.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.6/dist-packages (from mastml) (1.1.0)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.1.5)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from mastml) (1.15.0)
# Requirement already satisfied: tqdm>=4.23.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (4.41.1)
# Requirement already satisfied: folium>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.8.3)
# Requirement already satisfied: imgaug>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.2.9)
# Collecting pymatgen>=2019.1.24
#   Downloading https://files.pythonhosted.org/packages/e1/18/274b40cff34257a728071199d21105ced3116b42dd60793113eee7b1b5ca/pymatgen-2020.12.31.tar.gz (2.8MB)
#      |████████████████████████████████| 2.8MB 47.1MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.6/dist-packages (from mastml) (1.0.1)
# Collecting idna==2.7
#   Downloading https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 6.7MB/s
# Collecting globus-sdk
#   Downloading https://files.pythonhosted.org/packages/15/99/14c2f5562a98e34da90fdbccc9c6ac4518f4a4929b604f52ca4a95d49352/globus_sdk-1.10.0-py2.py3-none-any.whl (85kB)
#      |████████████████████████████████| 92kB 11.5MB/s
# Requirement already satisfied: retrying in /usr/local/lib/python3.6/dist-packages (from mastml) (1.3.3)
# Collecting citrination-client>=4.6.0
#   Downloading https://files.pythonhosted.org/packages/61/49/c0af91084172f6a6aa7d625651ec366c85a4fd717c5b4fa0e014d1953d6e/citrination-client-6.5.1.tar.gz (54kB)
#      |████████████████████████████████| 61kB 7.2MB/s
# Collecting pypif>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/1e/04/a59e5ebacaed2800678467d9fcf511d249bac9b1b692a8fba0072cb09a49/pypif-2.1.2.tar.gz
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from mastml) (3.2.2)
# Requirement already satisfied: tabulate>=0.8.2 in /usr/local/lib/python3.6/dist-packages (from mastml) (0.8.7)
# Collecting pyyaml>=4.2b1
#   Downloading https://files.pythonhosted.org/packages/4d/61/41f5949898f02e750d5d0773792ab4b80f948305ce47bb33c69147e217ba/PyYAML-5.4b1-cp36-cp36m-manylinux1_x86_64.whl (640kB)
#      |████████████████████████████████| 645kB 39.7MB/s
# Collecting pint>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/5f/0e/dd4fb17aed6bfbc168fd767cffb6ec20b634009b75fd8ea699ea244bff3c/Pint-0.16.1-py2.py3-none-any.whl (205kB)
#      |████████████████████████████████| 215kB 44.2MB/s
# Collecting nose>=1.3.7
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 46.7MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from mastml) (20.8)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.12->mastml) (3.7.4.3)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.6/dist-packages (from pytest>=5.0.1->mastml) (1.1.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.6/dist-packages (from pytest>=5.0.1->mastml) (0.10.2)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading https://files.pythonhosted.org/packages/88/ff/ec25dc01ef04232a9e68ff18492e37dfa01f1f58172e702ad4f38536d41b/ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549kB)
#      |████████████████████████████████| 552kB 42.4MB/s
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy>=1.2->mastml) (1.1.0)
# Collecting funcx>=0.0.5
#   Downloading https://files.pythonhosted.org/packages/5b/c0/359be86c580f0d261753651d4da4f15faa6f866be00613d2888035154d10/funcx-0.0.5-py3-none-any.whl
# Requirement already satisfied: sphinx>=1.7 in /usr/local/lib/python3.6/dist-packages (from sphinx-automodapi->mastml) (1.8.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.2.4->mastml) (2.10.0)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize>=0.5.2->mastml) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.2->mastml) (51.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.2->mastml) (0.17.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.6/dist-packages (from cryptography->mastml) (1.14.4)
# Collecting fair-research-login>=0.1.5
#   Downloading https://files.pythonhosted.org/packages/89/a6/3239efa5150d9cb52af90d246ca46a405eefdaee503e77bf84023dbd2752/fair_research_login-0.2.0-py2.py3-none-any.whl
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat->mastml) (4.7.0)
# Collecting ase
#   Downloading https://files.pythonhosted.org/packages/51/78/edadb45c7f26f8fbb99da81feadb561c26bb0393b6c5d1ac200ecdc12d61/ase-3.20.1-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 40.5MB/s
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from aflow->mastml) (1.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from aflow->mastml) (2.11.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from aflow->mastml) (4.6.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio>=2.3.0->mastml) (7.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from citeproc-py>=0.4->mastml) (4.2.6)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (2.4.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (0.36.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (1.6.3)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (0.10.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (0.3.3)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (1.32.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (3.12.4)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (1.1.2)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->mastml) (2.4.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium>=0.2.1->mastml) (0.4.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.2.5->mastml) (1.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.2.5->mastml) (4.1.2.30)
# Requirement already satisfied: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.2.5->mastml) (0.16.2)
# Collecting uncertainties>=3.1.4
#   Downloading https://files.pythonhosted.org/packages/45/41/fc7e7b73b603e7c2c9e040b7aa8caf4a88d74b6faa567601ed82b6f0d8e1/uncertainties-3.1.5-py2.py3-none-any.whl (246kB)
#      |████████████████████████████████| 256kB 48.6MB/s
# Requirement already satisfied: dataclasses>=0.6 in /usr/local/lib/python3.6/dist-packages (from pymatgen>=2019.1.24->mastml) (0.8)
# Collecting pyjwt[crypto]<2.0.0,>=1.5.3
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied: importlib-resources; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from pint>=0.8.1->mastml) (4.1.1)
# Collecting nbsphinx
#   Downloading https://files.pythonhosted.org/packages/6f/7a/9828e8981e472e717f695da957f52b389e91086532797005999342f487b5/nbsphinx-0.8.0-py3-none-any.whl
# Collecting texttable
#   Downloading https://files.pythonhosted.org/packages/06/f5/46201c428aebe0eecfa83df66bf3e6caa29659dbac5a56ddfd83cae0d4a4/texttable-1.6.3-py2.py3-none-any.whl
# Collecting typer>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/90/34/d138832f6945432c638f32137e6c79a3b682f06a63c488dcfaca6b166c64/typer-0.3.2-py3-none-any.whl
# Collecting sphinx-rtd-theme
#   Downloading https://files.pythonhosted.org/packages/76/81/d5af3a50a45ee4311ac2dac5b599d69f68388401c7a4ca902e0e450a9f94/sphinx_rtd_theme-0.5.1-py2.py3-none-any.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 48.1MB/s
# Collecting python-daemon
#   Downloading https://files.pythonhosted.org/packages/5a/0c/57f15b1572661877ff1acbe66c2f5be9d999ae5fb128e22933d374f62aa1/python_daemon-2.2.4-py2.py3-none-any.whl
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.6/dist-packages (from funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.3.3)
# Collecting parsl==0.9.0
#   Downloading https://files.pythonhosted.org/packages/ad/8b/91b10b35b9d43ba3fc456430a4c1b2b514d27623989d7354f2152c6bc8de/parsl-0.9.0-py3-none-any.whl (415kB)
#      |████████████████████████████████| 419kB 40.6MB/s
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (2.9.0)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (1.2.0)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (2.6.1)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (1.2.4)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (2.0.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (0.7.12)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.7->sphinx-automodapi->mastml) (0.16)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.12->cryptography->mastml) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->aflow->mastml) (1.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=1.13.1->mastml) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=1.13.1->mastml) (1.17.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=1.13.1->mastml) (1.7.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=1.13.1->mastml) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=1.13.1->mastml) (0.4.2)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug>=0.2.5->mastml) (1.1.1)
# Requirement already satisfied: nbconvert!=5.4 in /usr/local/lib/python3.6/dist-packages (from nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (5.6.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.6/dist-packages (from typer>=0.3.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (7.1.2)
# Collecting lockfile>=0.10
#   Downloading https://files.pythonhosted.org/packages/c8/22/9460e311f340cb62d26a38c419b1381b8593b0bb6b5d1f056938b086d362/lockfile-0.12.2-py2.py3-none-any.whl
# Requirement already satisfied: tblib in /usr/local/lib/python3.6/dist-packages (from parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (1.7.0)
# Collecting ipyparallel
#   Downloading https://files.pythonhosted.org/packages/3b/e9/03a9189eb39276396309faf28bf833b4328befe4513bbf375b811a36a076/ipyparallel-6.3.0-py3-none-any.whl (199kB)
#      |████████████████████████████████| 204kB 53.0MB/s
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (4.10.1)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (2.7.1)
# Collecting paramiko
#   Downloading https://files.pythonhosted.org/packages/95/19/124e9287b43e6ff3ebb9cdea3e5e8e88475a873c05ccdf8b7e20d2c4201e/paramiko-2.7.2-py2.py3-none-any.whl (206kB)
#      |████████████████████████████████| 215kB 54.4MB/s
# Requirement already satisfied: pyzmq>=17.1.2 in /usr/local/lib/python3.6/dist-packages (from parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (20.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.6/dist-packages (from sphinxcontrib-websupport->sphinx>=1.7->sphinx-automodapi->mastml) (1.1.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.13.1->mastml) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.13.1->mastml) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.13.1->mastml) (4.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.13.1->mastml) (1.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (1.4.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.4.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (3.2.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (5.3.5)
# Requirement already satisfied: ipython>=4 in /usr/local/lib/python3.6/dist-packages (from ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (5.5.0)
# Requirement already satisfied: tornado>=4 in /usr/local/lib/python3.6/dist-packages (from ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (5.1.1)
# Collecting bcrypt>=3.1.3
#   Downloading https://files.pythonhosted.org/packages/26/70/6d218afbe4c73538053c1016dd631e8f25fffc10cd01f5c272d7acf3c03d/bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63kB)
#      |████████████████████████████████| 71kB 5.6MB/s
# Collecting pynacl>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/9d/57/2f5e6226a674b2bcb6db531e8b383079b678df5b10cdaa610d6cf20d77ba/PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961kB)
#      |████████████████████████████████| 962kB 45.1MB/s
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.13.1->mastml) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.13.1->mastml) (3.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert!=5.4->nbsphinx->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.5.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4->ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4->ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4->ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4->ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4->ipyparallel->parsl==0.9.0->funcx>=0.0.5->dlhub-sdk>=0.9.3->mastml) (0.7.0)
# Building wheels for collected packages: configobj, duecredit, matminer, PyDispatcher, pymatgen, citrination-client, pypif
#   Building wheel for configobj (setup.py) ... done
#   Created wheel for configobj: filename=configobj-5.0.6-cp36-none-any.whl size=34545 sha256=aef88c5f64f6b8d136263422ee2f84f6ea45d87a8a07b93a9ab1a7cf3c39f7cb
#   Stored in directory: /root/.cache/pip/wheels/f1/e4/16/4981ca97c2d65106b49861e0b35e2660695be7219a2d351ee0
#   Building wheel for duecredit (setup.py) ... done
#   Created wheel for duecredit: filename=duecredit-0.8.0-cp36-none-any.whl size=76837 sha256=0fa47c11807e2036e748444ecd67385f3082fd8f7d080e20850548ba9a5f0d6f
#   Stored in directory: /root/.cache/pip/wheels/2a/88/56/1fc0eca601df7cef90c52307b76ded4f94c29f7c0ff76cc1d2
#   Building wheel for matminer (setup.py) ... done
#   Created wheel for matminer: filename=matminer-0.6.4-cp36-none-any.whl size=1172376 sha256=c82a5466cdc273c126d2d8a11453c9a51ad3fdfee1d2e0cd5409fff0c707be2b
#   Stored in directory: /root/.cache/pip/wheels/32/11/e1/9b7c6b6e5a76918455edf7c9aacbf6ec1a5db7fc46864cf119
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp36-none-any.whl size=11516 sha256=3de485b501a7723901b99ba0395b40eb6ab717bac8d1c53e0b7be7a293cadb19
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
#   Building wheel for pymatgen (setup.py) ... done
#   Created wheel for pymatgen: filename=pymatgen-2020.12.31-cp36-cp36m-linux_x86_64.whl size=3592732 sha256=ee5edc087a5d88ffc81215243ad597fc0a632cb8b3b2d0837b746707b596a08c
#   Stored in directory: /root/.cache/pip/wheels/bd/fd/4c/bbea735ca0989c51e67a45d1384b1ce3481bc2aa1337b4a6e9
#   Building wheel for citrination-client (setup.py) ... done
#   Created wheel for citrination-client: filename=citrination_client-6.5.1-py2.py3-none-any.whl size=116097 sha256=ea49cdb977e1a1fa1d98f711779199836535f5ca05b401b79f703bddb6b73315
#   Stored in directory: /root/.cache/pip/wheels/6c/88/f5/5a3d5759228aabc63cb3baf2d767369ac99d18f3a941d381e7
#   Building wheel for pypif (setup.py) ... done
#   Created wheel for pypif: filename=pypif-2.1.2-py2.py3-none-any.whl size=29506 sha256=92532609bca3b8a8b6de7ea225b644e70c839702e60735d27f020b0b5b95bb4c
#   Stored in directory: /root/.cache/pip/wheels/0d/19/de/9d99bb147337e90a209a44c89e67b3aaadcac4f6f8d106c13d
# Successfully built configobj duecredit matminer PyDispatcher pymatgen citrination-client pypif
# ERROR: nbclient 0.5.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: dlhub-sdk 0.9.4 has requirement mdf-toolbox>=0.5.4, but you'll have mdf-toolbox 0.5.1 which is incompatible.
# ERROR: dlhub-sdk 0.9.4 has requirement requests>=2.24.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: pymatgen 2020.12.31 has requirement scipy>=1.5.0, but you'll have scipy 1.4.1 which is incompatible.
# ERROR: matminer 0.6.4 has requirement future>=0.18.2, but you'll have future 0.16.0 which is incompatible.
# ERROR: matminer 0.6.4 has requirement tqdm>=4.46.0, but you'll have tqdm 4.41.1 which is incompatible.
# ERROR: jwt 1.1.0 has requirement cryptography<=3.2.1,>2.9.2, but you'll have cryptography 3.3.1 which is incompatible.
# Installing collected packages: configobj, citeproc-py, duecredit, dominate, cryptography, pyjwt, globus-sdk, globus-nexus-client, pluggy, pytest, ruamel.yaml.clib, ruamel.yaml, sympy, jsonschema, nbsphinx, texttable, typer, sphinx-rtd-theme, lockfile, python-daemon, fair-research-login, ipyparallel, psutil, bcrypt, pynacl, paramiko, parsl, funcx, mdf-toolbox, dlhub-sdk, monty, spglib, plotly, uncertainties, pymatgen, pint, threadpoolctl, scikit-learn, matminer, sphinx-automodapi, PyDispatcher, pyyaml, pyaml, scikit-optimize, forestci, mlxtend, xlsxwriter, jwt, mdf-forge, ase, aflow, idna, pypif, citrination-client, nose, mastml
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Found existing installation: sympy 1.1.1
#     Uninstalling sympy-1.1.1:
#       Successfully uninstalled sympy-1.1.1
#   Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
#   Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
#   Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
# Successfully installed PyDispatcher-2.0.5 aflow-0.0.11 ase-3.20.1 bcrypt-3.2.0 citeproc-py-0.5.1 citrination-client-6.5.1 configobj-5.0.6 cryptography-3.3.1 dlhub-sdk-0.9.4 dominate-2.6.0 duecredit-0.8.0 fair-research-login-0.2.0 forestci-0.4.1 funcx-0.0.5 globus-nexus-client-0.2.9 globus-sdk-1.10.0 idna-2.7 ipyparallel-6.3.0 jsonschema-3.2.0 jwt-1.1.0 lockfile-0.12.2 mastml-2.0.14 matminer-0.6.4 mdf-forge-0.7.6 mdf-toolbox-0.5.1 mlxtend-0.18.0 monty-4.0.2 nbsphinx-0.8.0 nose-1.3.7 paramiko-2.7.2 parsl-0.9.0 pint-0.16.1 plotly-4.14.3 pluggy-0.13.1 psutil-5.8.0 pyaml-20.4.0 pyjwt-1.7.1 pymatgen-2020.12.31 pynacl-1.4.0 pypif-2.1.2 pytest-6.2.1 python-daemon-2.2.4 pyyaml-5.4b1 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 scikit-learn-0.24.0 scikit-optimize-0.8.1 spglib-1.16.0 sphinx-automodapi-0.13 sphinx-rtd-theme-0.5.1 sympy-1.7.1 texttable-1.6.3 threadpoolctl-2.1.0 typer-0.3.2 uncertainties-3.1.5 xlsxwriter-1.3.7
# Collecting mdf_toolbox
#   Downloading https://files.pythonhosted.org/packages/f5/44/45ed3b256d744891384d13088c12a23baaa2e395b341c3ab03c18001f715/mdf_toolbox-0.5.7-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from mdf_toolbox) (2.23.0)
# Requirement already satisfied, skipping upgrade: globus-nexus-client>=0.2.8 in /usr/local/lib/python3.6/dist-packages (from mdf_toolbox) (0.2.9)
# Requirement already satisfied, skipping upgrade: globus-sdk>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from mdf_toolbox) (1.10.0)
# Requirement already satisfied, skipping upgrade: fair-research-login>=0.1.5 in /usr/local/lib/python3.6/dist-packages (from mdf_toolbox) (0.2.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->mdf_toolbox) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->mdf_toolbox) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->mdf_toolbox) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->mdf_toolbox) (2.7)
# Requirement already satisfied, skipping upgrade: six<2.0.0,>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from globus-nexus-client>=0.2.8->mdf_toolbox) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyjwt[crypto]<2.0.0,>=1.5.3 in /usr/local/lib/python3.6/dist-packages (from globus-sdk>=1.7.0->mdf_toolbox) (1.7.1)
# Requirement already satisfied, skipping upgrade: cryptography>=1.4; extra == "crypto" in /usr/local/lib/python3.6/dist-packages (from pyjwt[crypto]<2.0.0,>=1.5.3->globus-sdk>=1.7.0->mdf_toolbox) (3.3.1)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /usr/local/lib/python3.6/dist-packages (from cryptography>=1.4; extra == "crypto"->pyjwt[crypto]<2.0.0,>=1.5.3->globus-sdk>=1.7.0->mdf_toolbox) (1.14.4)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.12->cryptography>=1.4; extra == "crypto"->pyjwt[crypto]<2.0.0,>=1.5.3->globus-sdk>=1.7.0->mdf_toolbox) (2.20)
# ERROR: mastml 2.0.14 has requirement mdf-toolbox==0.5.1, but you'll have mdf-toolbox 0.5.7 which is incompatible.
# ERROR: dlhub-sdk 0.9.4 has requirement requests>=2.24.0, but you'll have requests 2.23.0 which is incompatible.
# Installing collected packages: mdf-toolbox
#   Found existing installation: mdf-toolbox 0.5.1
#     Uninstalling mdf-toolbox-0.5.1:
#       Successfully uninstalled mdf-toolbox-0.5.1
# Successfully installed mdf-toolbox-0.5.7
# Collecting scikit-learn==0.23.2
#   Downloading https://files.pythonhosted.org/packages/5c/a1/273def87037a7fb010512bbc5901c31cfddfca8080bc63b42b26e3cc55b3/scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 6.0MB/s
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.23.2) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.23.2) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.23.2) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.23.2) (1.0.0)
# ERROR: matminer 0.6.4 has requirement future>=0.18.2, but you'll have future 0.16.0 which is incompatible.
# ERROR: matminer 0.6.4 has requirement tqdm>=4.46.0, but you'll have tqdm 4.41.1 which is incompatible.
# ERROR: mastml 2.0.14 has requirement mdf-toolbox==0.5.1, but you'll have mdf-toolbox 0.5.7 which is incompatible.
# Installing collected packages: scikit-learn
#   Found existing installation: scikit-learn 0.24.0
#     Uninstalling scikit-learn-0.24.0:
#       Successfully uninstalled scikit-learn-0.24.0
# Successfully installed scikit-learn-0.23.2

# %%
# Sync your Google drive to Colab to save MASTML output to
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Restart runtime prior to import (Runtime -> Restart runtime -> Yes), otherwise will have errors
from mastml import mastml_driver
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Upload the example_input.conf and example_data.xlsx to the Google Colab runtime
input = 'example_input.conf'
data = 'example_data.xlsx'

# %%
# Perform MAST-ML run. Don't forget to download the saved run data or save it to 
# your Google Drive directly as Colab instance is wiped when exited.
mastml_driver.main(conf_path=input,
                   data_path=data,
                   outdir='/content/drive/My Drive/MASTML_example_output')
# Out:
# /content/drive/My Drive/MASTML_example_output not empty. Renaming...
# [INFO]
#
#    __  ___     __________    __  _____
#   /  |/  /__ _/ __/_  __/___/  |/  / /
#  / /|_/ / _ `/\ \  / / /___/ /|_/ / /__
# /_/  /_/\_,_/___/ /_/     /_/  /_/____/
#
#
# MAST-ML run on 2021-01-14 18:46:14 using
# conf file: example_input.conf
# csv file:  example_data.xlsx
# saving to: MASTML_example_output_01_14_18_46_14
#
#
# [INFO] Copying input files to output directory...
# [INFO] blacklisted features, either from "input_other" or a "input_grouping":['Material composition', 'Host element', 'Solute element', 'predict_Pt']
# [WARNING] You have chosen not to specify a method of data_cleaning in the input file. By default, any feature entries containing NaN will result in removal of the feature and any target data entries containing NaN will result in removal of that target data point.
# [DEBUG] splitter_to_group_names:
# {}
# [DEBUG] instantiation: KernelRidge, KernelRidge({'alpha': 0.009, 'gamma': 0.027, 'kernel': 'rbf'})
# [DEBUG] models, pre-snatching:
# OrderedDict([('KernelRidge', KernelRidge(alpha=0.009, gamma=0.027, kernel='rbf'))])
# [DEBUG] models, post-snatching:
# OrderedDict([('KernelRidge', KernelRidge(alpha=0.009, gamma=0.027, kernel='rbf'))])
# [DEBUG] instantiation: Magpie, Magpie({'composition_feature': 'Solute element', 'feature_types': ['composition_avg', 'arithmetic_avg', 'max', 'min', 'difference', 'elements']})
# [DEBUG] instantiation: StandardScaler, StandardScaler({})
# [DEBUG] instantiation: RepeatedKFold, RepeatedKFold({'n_splits': 3, 'n_repeats': 2})
# [DEBUG] cv, pre-snatching:
# OrderedDict([('RepeatedKFold', RepeatedKFold(n_repeats=2, n_splits=3, random_state=None))])
# [DEBUG] cv, post-snatching:
# OrderedDict([('RepeatedKFold', RepeatedKFold(n_repeats=2, n_splits=3, random_state=None))])
# [DEBUG] instantiation: DoNothing, DoNothing({})
# [DEBUG] generators:
# [['Magpie', Magpie(composition_feature='Solute element',
#        feature_types=['composition_avg', 'arithmetic_avg', 'max', 'min',
#                       'difference', 'elements'])]]
# [DEBUG] clusterers:
# []
# [DEBUG] normalizers:
# [['StandardScaler', StandardScaler()]]
# [DEBUG] hyperopts:
# []
# [DEBUG] selectors:
# [['DoNothing', DoNothing()]]
# [DEBUG] splitters:
# [('RepeatedKFold', RepeatedKFold(n_repeats=2, n_splits=3, random_state=None))]
# [INFO] There are 1 feature normalizers, 0 hyperparameter optimizers, 1 feature selectors, 1 models, and 1 splitters.
# [INFO] Doing feature generation...
# [WARNING] Dropping 11/512 generated columns due to missing values
# [INFO] Saving generated data to csv...
# [DEBUG] generated cols: Index(['AtomicNumber_arithmetic_average', 'AtomicNumber_composition_average',
#        'AtomicNumber_difference', 'AtomicNumber_max_value',
#        'AtomicNumber_min_value', 'AtomicRadii_arithmetic_average',
#        'AtomicRadii_composition_average', 'AtomicRadii_difference',
#        'AtomicRadii_max_value', 'AtomicRadii_min_value',
#        ...
#        'phi_arithmetic_average', 'phi_composition_average', 'phi_difference',
#        'phi_max_value', 'phi_min_value', 'valence_arithmetic_average',
#        'valence_composition_average', 'valence_difference',
#        'valence_max_value', 'valence_min_value'],
#       dtype='object', length=501)
# [INFO] Removing constant features, regardless of feature selectors.
# [WARNING] Removed 100/501 constant columns.
# [DEBUG] Removed the following constant columns: ['MeltingT_difference', 'ElectronAffinity_difference', 'Density_difference', 'IsAlkalineEarth_difference', 'n_ws^third_difference', 'NsUnfilled_difference', 'FirstIonizationEnergy_difference', 'AtomicNumber_difference', 'Element1_IsHalogen', 'IsHalogen_min_value', 'GSenergy_pa_difference', 'Row_difference', 'HeatCapacityMass_difference', 'IsNobleGas_difference', 'Column_difference', 'IsFCC_difference', 'IsNobleGas_min_value', 'GSestFCClatcnt_difference', 'IsHalogen_composition_average', 'valence_difference', 'IsHalogen_max_value', 'IonizationEnergy_difference', 'IsFBlock_difference', 'IsRhombohedral_difference', 'BCCvolume_padiff_difference', 'BCCenergy_pa_difference', 'Group_difference', 'IsNobleGas_composition_average', 'NValance_difference', 'IsNonmetal_difference', 'IonicRadii_difference', 'AtomicVolume_difference', 'NsValence_difference', 'Element1_IsNobleGas', 'GSmagmom_difference', 'Element1_IsSimpleCubic', 'SpaceGroupNumber_difference', 'IsSimpleCubic_max_value', 'ElasticModulus_difference', 'NUnfilled_difference', 'IsAlkali_difference', 'IsMetalloid_difference', 'HeatCapacityMolar_difference', 'IsTransitionMetal_difference', 'IsTetragonal_difference', 'Polarizability_difference', 'IsHexagonal_difference', 'NpValence_difference', 'IsBCC_difference', 'NdUnfilled_difference', 'NdValence_difference', 'IsNobleGas_arithmetic_average', 'ThermalConductivity_difference', 'IsSimpleCubic_composition_average', 'IsChalcogen_difference', 'IsSimpleCubic_arithmetic_average', 'GSbandgap_difference', 'CovalentRadius_difference', 'AtomicRadii_difference', 'IsDBlock_difference', 'phi_difference', 'AtomicWeight_difference', 'IsMetal_difference', 'IsCarbon_difference', 'NfValence_difference', 'ThirdIonizationEnergy_difference', 'BulkModulus_difference', 'MendeleevNumber_difference', 'NpUnfilled_difference', 'IsSimpleCubic_difference', 'ElectricalConductivity_difference', 'CovalentRadii_difference', 'SecondIonizationEnergy_difference', 'ThermalExpansionCoefficient_difference', 'BCCmagmom_difference', 'IsPnictide_difference', 'BCCfermi_difference', 'Electronegativity_difference', 'SpecificHeatCapacity_difference', 'IsOrthorhombic_difference', 'HHIp_difference', 'Number_difference', 'HeatVaporization_difference', 'IsSimpleCubic_min_value', 'IsMonoclinic_difference', 'GSestBCClatcnt_difference', 'MiracleRadius_difference', 'IsBoron_difference', 'IsRareEarth_difference', 'NfUnfilled_difference', 'BCCvolume_pa_difference', 'ShearModulus_difference', 'ICSDVolume_difference', 'BoilingT_difference', 'IsHalogen_difference', 'HeatFusion_difference', 'GSvolume_pa_difference', 'IsHalogen_arithmetic_average', 'IsNobleGas_max_value', 'Period_difference']
# [INFO] Saving generated data without constant columns to csv...
# [INFO] Doing clustering...
# [INFO] Saving clustered data to csv...
# [INFO] Running normalizer StandardScaler ...
# [INFO] Saving normalized data to csv...
# [INFO] Running selectors...
# [INFO]     Running selector DoNothing ...
# [INFO]     Saving selected features to csv...
# [DEBUG] Finding splitter-required columns in data...
# [INFO] Fitting models to splits...
# [INFO]     Running splits for StandardScaler/DoNothing/KernelRidge/RepeatedKFold
# [INFO]         Doing split number 0
# [INFO]              Fitting model and making predictions...
# [INFO]              Making predictions on prediction_only data...
# [INFO]              Saving train/test data and predictions to csv...
# [INFO]              Calculating score metrics...
# [INFO]              Making plots...
# [INFO]         Doing split number 1
# [INFO]              Fitting model and making predictions...
# [INFO]              Making predictions on prediction_only data...
# [INFO]              Saving train/test data and predictions to csv...
# [INFO]              Calculating score metrics...
# [INFO]              Making plots...
# [INFO]         Doing split number 2
# [INFO]              Fitting model and making predictions...
# [INFO]              Making predictions on prediction_only data...
# [INFO]              Saving train/test data and predictions to csv...
# [INFO]              Calculating score metrics...
# [INFO]              Making plots...
# [INFO]         Doing split number 3
# [INFO]              Fitting model and making predictions...
# [INFO]              Making predictions on prediction_only data...
# [INFO]              Saving train/test data and predictions to csv...
# [INFO]              Calculating score metrics...
# [INFO]              Making plots...
# [INFO]         Doing split number 4
# [INFO]              Fitting model and making predictions...
# [INFO]              Making predictions on prediction_only data...
# [INFO]              Saving train/test data and predictions to csv...
# [INFO]              Calculating score metrics...
# [INFO]              Making plots...
# [INFO]         Doing split number 5
# [INFO]              Fitting model and making predictions...
# [INFO]              Making predictions on prediction_only data...
# [INFO]              Saving train/test data and predictions to csv...
# [INFO]              Calculating score metrics...
# [INFO]              Making plots...
# [INFO]     Calculating mean and stdev of scores...
# [INFO]     Making best/worst plots...
# [INFO] Making image html file...
# [INFO] wrote /content/drive/My Drive/MASTML_example_output_01_14_18_46_14/index.html
# [INFO] Making html file of all runs stats...
# [INFO] Your MAST-ML run has finished successfully!
# '/content/drive/My Drive/MASTML_example_output_01_14_18_46_14'
